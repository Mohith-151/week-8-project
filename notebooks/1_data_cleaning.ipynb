# %% [markdown]
# ### Data loading

# %%
import pandas as pd

df = pd.read_csv('../data/raw_data.csv')

# %%
print("--- FIRST 5 ROWS ---")
print(df.head())
# Out:
# --- FIRST 5 ROWS ---
#   CustomerID  Tenure  MonthlyCharges  TotalCharges        Contract  \
# 0     C00001       6              64          1540        One year
# 1     C00002      21             113          1753  Month-to-month
# 2     C00003      27              31          1455        Two year
# 3     C00004      53              29          7150  Month-to-month
# 4     C00005      16             185          1023        One year
#
#       PaymentMethod PaperlessBilling  SeniorCitizen  Churn
# 0       Credit Card               No              1      0
# 1  Electronic Check              Yes              1      0
# 2       Credit Card               No              1      0
# 3  Electronic Check               No              1      0
# 4  Electronic Check               No              1      0

# %%
print("\n--- DATA TYPES & NULL VALUES ---")
print(df.info())
# Out:
# --- DATA TYPES & NULL VALUES ---
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        500 non-null    str
#  1   Tenure            500 non-null    int64
#  2   MonthlyCharges    500 non-null    int64
#  3   TotalCharges      500 non-null    int64
#  4   Contract          500 non-null    str
#  5   PaymentMethod     500 non-null    str
#  6   PaperlessBilling  500 non-null    str
#  7   SeniorCitizen     500 non-null    int64
#  8   Churn             500 non-null    int64
# dtypes: int64(5), str(4)
# memory usage: 50.8 KB
# None

# %%
print("\n--- MISSING VALUE COUNT ---")
print(df.isnull().sum())
# Out:
# --- MISSING VALUE COUNT ---
# CustomerID          0
# Tenure              0
# MonthlyCharges      0
# TotalCharges        0
# Contract            0
# PaymentMethod       0
# PaperlessBilling    0
# SeniorCitizen       0
# Churn               0
# dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0    447
# 1     53
# Name: count, dtype: int64

# %% [markdown]
# 0 = stayed.
# 1 = left.
#
# so 53 coustomers left

# %%
# Check for duplicate rows
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
# Data Integrity Check 
# if tenure is 6 months and monthly is 64, Total should be ~384, but it's 1540
# I think 'TotalCharges' might include setup fees or historical data. 
# For now, we will keep it as is.

# %%
# saving this cleaned data for EDA phase
df.to_csv('../data/cleaned_data.csv', index=False)
print("File saved successfully as cleaned_data.csv!")
# Out:
# File saved successfully as cleaned_data.csv!

# %%
from sklearn.preprocessing import LabelEncoder

#copy of original dataset.
df_encoded = df.copy()

le = LabelEncoder()

cat_cols = ['Contract', 'PaymentMethod', 'PaperlessBilling']


for col in cat_cols:
    df_encoded[col] = le.fit_transform(df[col])
    print(f"Encoded {col}: {dict(zip(le.classes_, le.transform(le.classes_)))}")

# Saving this version separately for Phase 4
df_encoded.to_csv('../data/encoded_data.csv', index=False)
# Out:
# Encoded Contract: {'Month-to-month': np.int64(0), 'One year': np.int64(1), 'Two year': np.int64(2)}
# Encoded PaymentMethod: {'Bank Transfer': np.int64(0), 'Credit Card': np.int64(1), 'Electronic Check': np.int64(2)}
# Encoded PaperlessBilling: {'No': np.int64(0), 'Yes': np.int64(1)}
